# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import squarify

# %%
file = "SF_foodstoreData.csv"

foodstores_df = pd.read_csv(file)
foodstores_df
# Out:
#                                Factual ID          Name  \
# 0    88dc1adc-32d9-4afe-9da8-2d770a6703c6       Safeway
# 1    77fd78bb-ed15-4cb4-8008-bb8379450132         Lucky
# 2    7c59b6d6-00aa-46c7-a523-0819dcb85a64   Whole Foods
# 3    fa629981-f247-4131-822d-a31e160b3ebe       Safeway
# 4    ddef2730-8622-4f4e-8cd6-d6260863bee3  Trader Joe's
# ..                                    ...           ...
# 313                                   NaN           NaN
# 314                                   NaN           NaN
# 315                                   NaN           NaN
# 316                                   NaN           NaN
# 317                                   NaN           NaN
#
#                        Address Locality (Town/City) Region (State/Province)  \
# 0    5290 Diamond Heights Blvd        San Francisco                      CA
# 1              1515 Sloat Blvd        San Francisco                      CA
# ...

# %%
foodcounts_df = foodstores_df.groupby("Category Labels").size().reset_index(name="Counts")
labels = foodcounts_df.apply(lambda x: str(x[0]) + "\n (" + str(x[1]) + ")", axis=1)
sizes = foodcounts_df["Counts"].values.tolist()
colors = [plt.cm.Spectral(i/float(len(labels))) for i in range(len(labels))]

plt.figure(figsize=(12,8), dpi= 80)
squarify.plot(sizes=sizes, label=labels, color=colors, alpha=.8)

plt.title('Treemap of Store Types in San Francisco', fontsize=22)
plt.axis('off')
plt.show()
