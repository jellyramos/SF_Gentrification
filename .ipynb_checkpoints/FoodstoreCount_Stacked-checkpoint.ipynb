# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
file = "SF_foodstoreData.csv"

foodstores_raw = pd.read_csv(file)
foodstores_raw
# Out:
#                                Factual ID          Name  \
# 0    88dc1adc-32d9-4afe-9da8-2d770a6703c6       Safeway
# 1    77fd78bb-ed15-4cb4-8008-bb8379450132         Lucky
# 2    7c59b6d6-00aa-46c7-a523-0819dcb85a64   Whole Foods
# 3    fa629981-f247-4131-822d-a31e160b3ebe       Safeway
# 4    ddef2730-8622-4f4e-8cd6-d6260863bee3  Trader Joe's
# ..                                    ...           ...
# 313                                   NaN           NaN
# 314                                   NaN           NaN
# 315                                   NaN           NaN
# 316                                   NaN           NaN
# 317                                   NaN           NaN
#
#                        Address Locality (Town/City) Region (State/Province)  \
# 0    5290 Diamond Heights Blvd        San Francisco                      CA
# 1              1515 Sloat Blvd        San Francisco                      CA
# ...

# %%
del foodstores_raw["Unnamed: 14"]
foodstores_raw
# Out:
#                                Factual ID          Name  \
# 0    88dc1adc-32d9-4afe-9da8-2d770a6703c6       Safeway
# 1    77fd78bb-ed15-4cb4-8008-bb8379450132         Lucky
# 2    7c59b6d6-00aa-46c7-a523-0819dcb85a64   Whole Foods
# 3    fa629981-f247-4131-822d-a31e160b3ebe       Safeway
# 4    ddef2730-8622-4f4e-8cd6-d6260863bee3  Trader Joe's
# ..                                    ...           ...
# 313                                   NaN           NaN
# 314                                   NaN           NaN
# 315                                   NaN           NaN
# 316                                   NaN           NaN
# 317                                   NaN           NaN
#
#                        Address Locality (Town/City) Region (State/Province)  \
# 0    5290 Diamond Heights Blvd        San Francisco                      CA
# 1              1515 Sloat Blvd        San Francisco                      CA
# ...

# %%
foodstores_df = foodstores_raw.drop(foodstores_raw.index[[312,313,314,315,316,317]])
foodstores_df
# Out:
#                                Factual ID                          Name  \
# 0    88dc1adc-32d9-4afe-9da8-2d770a6703c6                       Safeway
# 1    77fd78bb-ed15-4cb4-8008-bb8379450132                         Lucky
# 2    7c59b6d6-00aa-46c7-a523-0819dcb85a64                   Whole Foods
# 3    fa629981-f247-4131-822d-a31e160b3ebe                       Safeway
# 4    ddef2730-8622-4f4e-8cd6-d6260863bee3                  Trader Joe's
# ..                                    ...                           ...
# 307  2dcd9833-3a98-40ee-8d16-8782c3eb8af6               Friendly Liquor
# 308  7ff833e0-3d61-44ac-b659-5c8dbb73fb9a           Cameron Hughes Wine
# 309  49128df2-3026-4093-89d5-0069121c8d64                Lawton Liquors
# 310  04c9dcc8-3d98-4268-9673-594b4b7d1be1     Samy's Liquor & Groceries
# 311  1b004b5f-70f5-4dcf-91df-84b90a5f03ab  Fred's Liquor & Delicatessen
#
#                        Address Locality (Town/City) Region (State/Province)  \
# ...

# %%
foodstores_df.dtypes
# Out:
# Factual ID                  object
# Name                        object
# Address                     object
# Locality (Town/City)        object
# Region (State/Province)     object
# Post Code                  float64
# Country                     object
# Neighborhood                object
# Tel                         object
# Website                     object
# Latitude                   float64
# Longitude                  float64
# Category Labels             object
# Chain Name                  object
# dtype: object

# %%
# foodstores_df["Post Code"] = foodstores_df["Post Code"].apply(str)
# foodstores_df["Category Labels"]=foodstores_df["Category Labels"].astype("category")

# %%
foodstores_df.dtypes
# Out:
# Factual ID                  object
# Name                        object
# Address                     object
# Locality (Town/City)        object
# Region (State/Province)     object
# Post Code                   object
# Country                     object
# Neighborhood                object
# Tel                         object
# Website                     object
# Latitude                   float64
# Longitude                  float64
# Category Labels             object
# Chain Name                  object
# dtype: object

# %%
x_var = "Post Code"
groupby_var = "Category Labels"
df_agg = foodstores_df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [foodstores_df[x_var].values.tolist() for i, foodstores_df in df_agg]

# %%
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, foodstores_df[x_var].unique().__len__(), stacked=True, density=False, color=colors[:len(vals)])

plt.legend({group:col for group, col in zip(np.unique(foodstores_df[groupby_var]).tolist(), colors[:len(vals)])}, loc='upper right')
plt.title("Food Store Types in San Franciscso by Post Code", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Number of Stores")
plt.ylim(0, 30)
plt.xticks(ticks=bins, labels=np.unique(foodstores_df[x_var]).tolist(), rotation=45, horizontalalignment='left')
plt.show()
